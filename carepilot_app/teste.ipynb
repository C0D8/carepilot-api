# %%
import pandas as pd

# %%
df  = pd.read_csv('movimento_anonimo.csv', sep = ';')
#coloque em um arquivo de texto  dicionario em formato dict records 

df.head()

df.to_dict(orient = 'records')
# Out:
# [{'cliente_id': 1,
#   'produto_id': 2,
#   'quantidade': 1,
#   'valor_total': '192,9000',
#   'data': '19/04/2023 00:00:00'},
#  {'cliente_id': 1000003,
#   'produto_id': 51,
#   'quantidade': 1,
#   'valor_total': '19,5000',
#   'data': '25/04/2023 00:00:00'},
#  {'cliente_id': 1000003,
#   'produto_id': 50,
#   'quantidade': 1,
#   'valor_total': '28,0000',
#   'data': '25/04/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1098,
#   'quantidade': 1,
#   'valor_total': '23,9000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1000004,
#   'produto_id': 1477,
#   'quantidade': 1,
#   'valor_total': '15,0000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 716,
#   'quantidade': 1,
#   'valor_total': '5,5000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 111,
#   'quantidade': 1,
#   'valor_total': '5,5000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1735,
#   'quantidade': 3,
#   'valor_total': '3,0000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1414,
#   'quantidade': 2,
#   'valor_total': '2,0000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1790,
#   'quantidade': 1,
#   'valor_total': '0,2500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 777,
#   'quantidade': 1,
#   'valor_total': '3,0000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1305,
#   'quantidade': 1,
#   'valor_total': '296,7200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1083,
#   'quantidade': 2,
#   'valor_total': '35,8000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 2,
#   'quantidade': 14,
#   'valor_total': '0,1401',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 3,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 4,
#   'quantidade': 10,
#   'valor_total': '0,0999',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 5,
#   'quantidade': 7,
#   'valor_total': '0,0701',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 6,
#   'quantidade': 11,
#   'valor_total': '0,1101',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 7,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 8,
#   'quantidade': 15,
#   'valor_total': '0,1499',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 9,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 10,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 11,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 12,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 15,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 16,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 18,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 19,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 20,
#   'quantidade': 52,
#   'valor_total': '0,5200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 21,
#   'quantidade': 36,
#   'valor_total': '0,3600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 22,
#   'quantidade': 115,
#   'valor_total': '1,1500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 23,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 24,
#   'quantidade': 16,
#   'valor_total': '0,1600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 25,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 26,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 27,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 30,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 31,
#   'quantidade': 17,
#   'valor_total': '0,1700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 40,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 41,
#   'quantidade': 75,
#   'valor_total': '0,7500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 45,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 49,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 50,
#   'quantidade': 25,
#   'valor_total': '0,2500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 60,
#   'quantidade': 789,
#   'valor_total': '7,8900',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 68,
#   'quantidade': 48,
#   'valor_total': '0,4799',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 71,
#   'quantidade': 12,
#   'valor_total': '0,1200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 77,
#   'quantidade': 16,
#   'valor_total': '0,1600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 79,
#   'quantidade': 114,
#   'valor_total': '1,1400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 80,
#   'quantidade': 20,
#   'valor_total': '0,2000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 83,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 89,
#   'quantidade': 23,
#   'valor_total': '0,2300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 90,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 91,
#   'quantidade': 4972,
#   'valor_total': '49,7117',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 92,
#   'quantidade': 4651,
#   'valor_total': '46,5022',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 94,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 100,
#   'quantidade': 103,
#   'valor_total': '1,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 102,
#   'quantidade': 10,
#   'valor_total': '0,1000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 110,
#   'quantidade': 12,
#   'valor_total': '0,1200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 111,
#   'quantidade': 16,
#   'valor_total': '0,1600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 112,
#   'quantidade': 14,
#   'valor_total': '0,1400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 113,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 118,
#   'quantidade': 40,
#   'valor_total': '0,4000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 124,
#   'quantidade': 35,
#   'valor_total': '0,3500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 126,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 127,
#   'quantidade': 10,
#   'valor_total': '0,1000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 133,
#   'quantidade': 69,
#   'valor_total': '0,6900',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 134,
#   'quantidade': 55,
#   'valor_total': '0,5500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 138,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 140,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 141,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 151,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 152,
#   'quantidade': 10,
#   'valor_total': '0,0999',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 153,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 154,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 155,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 156,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 157,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 158,
#   'quantidade': 13,
#   'valor_total': '0,1300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 159,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 160,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 161,
#   'quantidade': 3,
#   'valor_total': '0,0299',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 162,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 163,
#   'quantidade': 9,
#   'valor_total': '0,0900',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 164,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 165,
#   'quantidade': 10,
#   'valor_total': '0,1000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 166,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 167,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 168,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 169,
#   'quantidade': 29,
#   'valor_total': '0,2900',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 173,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 175,
#   'quantidade': 12,
#   'valor_total': '0,1201',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 176,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 178,
#   'quantidade': 8,
#   'valor_total': '0,0800',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 179,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 180,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 181,
#   'quantidade': 9,
#   'valor_total': '0,0900',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 183,
#   'quantidade': 25,
#   'valor_total': '0,2501',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 184,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 185,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 186,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 187,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 188,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 189,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 190,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 191,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 194,
#   'quantidade': 10,
#   'valor_total': '0,1000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 195,
#   'quantidade': 20,
#   'valor_total': '0,2000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 197,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 198,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 199,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 201,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 202,
#   'quantidade': 8,
#   'valor_total': '0,0800',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 203,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 206,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 207,
#   'quantidade': 20,
#   'valor_total': '0,2000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 208,
#   'quantidade': 36,
#   'valor_total': '0,3600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 209,
#   'quantidade': 41,
#   'valor_total': '0,4100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 210,
#   'quantidade': 40,
#   'valor_total': '0,3999',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 211,
#   'quantidade': 34,
#   'valor_total': '0,3399',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 212,
#   'quantidade': 36,
#   'valor_total': '0,3599',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 213,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 215,
#   'quantidade': 34,
#   'valor_total': '0,3400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 216,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 217,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 218,
#   'quantidade': 57,
#   'valor_total': '0,5700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 220,
#   'quantidade': 107,
#   'valor_total': '1,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 221,
#   'quantidade': 52,
#   'valor_total': '0,5200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 222,
#   'quantidade': 38,
#   'valor_total': '0,3800',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 223,
#   'quantidade': 15,
#   'valor_total': '0,1500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 224,
#   'quantidade': 13,
#   'valor_total': '0,1300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 225,
#   'quantidade': 20,
#   'valor_total': '0,2000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 227,
#   'quantidade': 31,
#   'valor_total': '0,3099',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 228,
#   'quantidade': 17,
#   'valor_total': '0,1700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 229,
#   'quantidade': 92,
#   'valor_total': '0,9200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 230,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 231,
#   'quantidade': 8,
#   'valor_total': '0,0800',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 232,
#   'quantidade': 16,
#   'valor_total': '0,1602',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 233,
#   'quantidade': 160,
#   'valor_total': '1,6000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 234,
#   'quantidade': 61,
#   'valor_total': '0,6100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 235,
#   'quantidade': 15,
#   'valor_total': '0,1500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 236,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 240,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 244,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 246,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 247,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 248,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 249,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 251,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 252,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 253,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 255,
#   'quantidade': 11,
#   'valor_total': '0,1099',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 256,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 257,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 259,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 261,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 262,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 264,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 265,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 266,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 270,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 271,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 273,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 282,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 285,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 287,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 288,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 291,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 292,
#   'quantidade': 4,
#   'valor_total': '0,0399',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 293,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 294,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 295,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 296,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 303,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 309,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 310,
#   'quantidade': 12,
#   'valor_total': '0,1200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 311,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 312,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 313,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 314,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 316,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 317,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 319,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 324,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 325,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 326,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 327,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 328,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 329,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 332,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 333,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 334,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 335,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 337,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 338,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 339,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 340,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 341,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 346,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 347,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 348,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 349,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 351,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 358,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 360,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 362,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 363,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 364,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 365,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 366,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 367,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 368,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 369,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 372,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 373,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 374,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 375,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 378,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 379,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 381,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 382,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 383,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 387,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 390,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 391,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 392,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 393,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 394,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 396,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 397,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 398,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 399,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 400,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 402,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 404,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 417,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 418,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 419,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 420,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 421,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 422,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 423,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 424,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 425,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 426,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 433,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 434,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 435,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 436,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 437,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 438,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 442,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 444,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 445,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 447,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 448,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 449,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 455,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 456,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 458,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 460,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 461,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 462,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 465,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 466,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 467,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 470,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 471,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 472,
#   'quantidade': 5,
#   'valor_total': '0,0499',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 473,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 476,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 477,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 478,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 479,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 480,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 482,
#   'quantidade': 8,
#   'valor_total': '0,0800',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 483,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 485,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 488,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 490,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 492,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 494,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 497,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 500,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 501,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 502,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 504,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 505,
#   'quantidade': 39,
#   'valor_total': '0,3899',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 507,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 514,
#   'quantidade': 12,
#   'valor_total': '0,1200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 515,
#   'quantidade': 10,
#   'valor_total': '0,1000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 517,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 520,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 521,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 522,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 523,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 524,
#   'quantidade': 24,
#   'valor_total': '0,2400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 525,
#   'quantidade': 30,
#   'valor_total': '0,3000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 529,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 534,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 536,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 538,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 539,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 540,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 541,
#   'quantidade': 8,
#   'valor_total': '0,0800',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 542,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 549,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 563,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 567,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 568,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 569,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 570,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 571,
#   'quantidade': 13,
#   'valor_total': '0,1300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 572,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 575,
#   'quantidade': 8,
#   'valor_total': '0,0800',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 577,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 578,
#   'quantidade': 3,
#   'valor_total': '0,0299',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 579,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 580,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 581,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 582,
#   'quantidade': 16,
#   'valor_total': '0,1600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 583,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 584,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 585,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 586,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 589,
#   'quantidade': 3026,
#   'valor_total': '30,2600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 591,
#   'quantidade': 2717,
#   'valor_total': '27,1700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 592,
#   'quantidade': 1939,
#   'valor_total': '19,3900',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 593,
#   'quantidade': 2444,
#   'valor_total': '24,4400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 594,
#   'quantidade': 1621,
#   'valor_total': '16,2100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 595,
#   'quantidade': 2732,
#   'valor_total': '27,3200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 602,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 603,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 604,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 605,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 606,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 607,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 608,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 609,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 610,
#   'quantidade': 14,
#   'valor_total': '0,1400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 612,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 613,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 614,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 618,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 625,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 626,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 637,
#   'quantidade': 50,
#   'valor_total': '0,5000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 638,
#   'quantidade': 16,
#   'valor_total': '0,1600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 651,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 659,
#   'quantidade': 20,
#   'valor_total': '0,2000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 660,
#   'quantidade': 18,
#   'valor_total': '0,1800',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 661,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 662,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 663,
#   'quantidade': 13,
#   'valor_total': '0,1300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 665,
#   'quantidade': 32,
#   'valor_total': '0,3203',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 670,
#   'quantidade': 12,
#   'valor_total': '0,1200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 671,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 683,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 687,
#   'quantidade': 8,
#   'valor_total': '0,0800',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 688,
#   'quantidade': 8,
#   'valor_total': '0,0800',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 689,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 690,
#   'quantidade': 8,
#   'valor_total': '0,0800',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 691,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 692,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 693,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 694,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 695,
#   'quantidade': 1,
#   'valor_total': '0,0101',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 696,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 698,
#   'quantidade': 7,
#   'valor_total': '0,0700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 700,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 702,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 703,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 707,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 708,
#   'quantidade': 10,
#   'valor_total': '0,1000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 709,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 710,
#   'quantidade': 1,
#   'valor_total': '0,0156',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 711,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 712,
#   'quantidade': 41,
#   'valor_total': '0,4099',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 713,
#   'quantidade': 16,
#   'valor_total': '0,1600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 716,
#   'quantidade': 212,
#   'valor_total': '2,1200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 718,
#   'quantidade': 15,
#   'valor_total': '0,1500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 731,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 733,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 734,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 736,
#   'quantidade': 180,
#   'valor_total': '1,8000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 737,
#   'quantidade': 43,
#   'valor_total': '0,4300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 740,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 743,
#   'quantidade': 120,
#   'valor_total': '1,2000',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 744,
#   'quantidade': 45,
#   'valor_total': '0,4500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 747,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 750,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 754,
#   'quantidade': 62,
#   'valor_total': '0,6200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 755,
#   'quantidade': 17,
#   'valor_total': '0,1700',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 756,
#   'quantidade': 11,
#   'valor_total': '0,1100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 757,
#   'quantidade': 39,
#   'valor_total': '0,3900',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 759,
#   'quantidade': 21,
#   'valor_total': '0,2100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 760,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 761,
#   'quantidade': 9,
#   'valor_total': '0,0900',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 762,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
# ...
#  {'cliente_id': 1,
#   'produto_id': 1537,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1538,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1539,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1540,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1541,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1543,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1545,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1546,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1547,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1548,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1549,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1550,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1551,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1552,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1553,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1556,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1558,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1559,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1560,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1561,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1562,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1563,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1564,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1565,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1566,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1567,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1569,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1570,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1571,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1572,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1573,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1577,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1578,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1579,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1580,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1581,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1583,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1584,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1585,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1586,
#   'quantidade': 9,
#   'valor_total': '0,0900',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1588,
#   'quantidade': 9,
#   'valor_total': '0,0900',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1589,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1591,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1594,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1595,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1596,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1597,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1598,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1600,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1605,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1606,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1607,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1608,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1609,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1610,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1611,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1612,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1613,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1614,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1615,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1617,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1618,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1620,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1621,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1622,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1624,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1625,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1626,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1627,
#   'quantidade': 5,
#   'valor_total': '0,0500',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1628,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1629,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1630,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1631,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1632,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1633,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1634,
#   'quantidade': 9,
#   'valor_total': '0,0900',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1635,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1636,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1637,
#   'quantidade': 6,
#   'valor_total': '0,0600',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1638,
#   'quantidade': 11,
#   'valor_total': '0,1100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1639,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1640,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1641,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1643,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1644,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1645,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1646,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1651,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1652,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1653,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1654,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1655,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1656,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1657,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1658,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1659,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1660,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1661,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1662,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1663,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1664,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1665,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1666,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1667,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1668,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1669,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1670,
#   'quantidade': 4,
#   'valor_total': '0,0400',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1671,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1672,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1674,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1675,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1676,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1678,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1679,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1680,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1681,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1682,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1683,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1684,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1686,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1687,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1688,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1689,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1690,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1692,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1695,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1696,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1698,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1699,
#   'quantidade': 2,
#   'valor_total': '0,0200',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1700,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1701,
#   'quantidade': 1,
#   'valor_total': '0,0100',
#   'data': '02/05/2023 00:00:00'},
#  {'cliente_id': 1,
#   'produto_id': 1702,
#   'quantidade': 3,
#   'valor_total': '0,0300',
#   'data': '02/05/2023 00:00:00'},
#  ...]
